1.4823554651501816,1.1325040163001359,3.240812579403995,0.6200383836702039,-2.3083443059955844,2.5696535833947833,2.36309147209432,1.8800264286646609,6.467252349847418,-4.965724667574993,10.09962827083213,10.140981086049518,-0.58856049157752,5.115746911249532,-0.5788552819617028,-4.9653876148162785,10.493608466261083,-1.95766555896734,-3.188195595350109,2.368770443715084,1.179016169585369,2.3640644895441145,0.21766831711560997,2.310474950515813,1.5727562650484082,3.5370442697925455,-1.3443382798593717,-0.4835138627352289,-4.659226533732001,3.454057808419538,-5.775794788134675,-0.9583431635605588,6.922994369413872,-6.522375923069209,-3.829670619003516,3.8285957614836628,0.6047111863960551,-0.9474785664873107,1.697861435465736,3.842624317157716,-0.5885952781042771,6.245046871048473,8.263158068781287,6.2157672023853605,7.146770845185512,-0.30810374547423725,5.1288229440117865,1.905196049753108,-3.478255667168538,5.766156653276722,-0.515203466020079,1.8750770344496308,-7.628858327722776,1.066832910797304,3.9988503319949986,5.570260039495699,-1.3761843566856786,3.4328701385838314,-0.7383668484922155,4.401112633092365,0.03330124689958558,2.695901169247872,5.103431017373107,-4.860923853531092,0.2567264293124394,-7.426861723726583,1.3319917296355848,2.952409261966312,2.8020800037844786,4.055234153708732,7.872830363851037,4.04017817624296,6.478102832275019,1.4103600533838323,6.294314928372593,-7.4645459287046805,2.054183794046285,3.7314030860000877,7.723771730142497,0.9607306922877972,-4.2713303280388875,-7.715328058532696]

# %%
pj = 0.99
J = np.array([[pj+(1.0 - pj)/3.0, (1.0 - pj)/3.0, (1.0 - pj)/3.0],
              [(1.0 - pj)/3.0, pj+(1.0 - pj)/3.0, (1.0 - pj)/3.0],
              [(1.0 - pj)/3.0, (1.0 - pj)/3.0, pj+(1.0 - pj)/3.0]])
s = np.array([1.0/3.0, 1.0/3.0, 1.0/3.0])


mu_ = sum(train)/len(train)
print(mu_test, sig_test, mu_, sig_)

alphas = []
vs = []
for n in range(0, len(rhs)):
    alpha_n =  (rhs[n] - mu_)**2   
    l = len([v for v in alphas if v < alpha_n])
    e = len([v for v in alphas if v == alpha_n])
    theta = random.uniform(0, 1)
    alphas.append(alpha_n)    
    p = (l + theta * e)/float(len(alphas))
    e0 = 1.0 - (p - 0.5)
    e1 = 1.0
    e2 = 1.0 + (p - 0.5)
    stmp = (s @ J) * np.array([e0,e1,e2])
    val = stmp[0] + stmp[1] + stmp[2]
    vs.append(val)
    s = stmp

plt.scatter([range(0, len(vs[0:]))], vs[0:])
vs[1], vs[51], vs[101], vs[151], vs[199]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 pj = 0.9
# ----> 2 J = np.array([[pj+(1.0 - pj)/3.0, (1.0 - pj)/3.0, (1.0 - pj)/3.0],
#       3               [(1.0 - pj)/3.0, pj+(1.0 - pj)/3.0, (1.0 - pj)/3.0],
#       4               [(1.0 - pj)/3.0, (1.0 - pj)/3.0, pj+(1.0 - pj)/3.0]])
#       5 s = np.array([1.0/3.0, 1.0/3.0, 1.0/3.0])
#       8 mu_ = sum(train)/len(train)
#
# NameError: name 'np' is not defined

# %%
#outf = open("dump.txt", "w")
#outf.write(",".join(list([str(x) for x in train])) + "\n")
#outf.write(",".join(list([str(x) for x in rhs]))  + "\n")
#outf.close()
